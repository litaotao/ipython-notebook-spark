# %%
from pyspark import SparkConf, SparkContext
import pyspark.streaming as streaming

# %%
conf = SparkConf().setAppName("spark fire 4").setMaster("spark://10.21.208.21:7077")
sc = SparkContext(conf=conf)

# %%
url = u"https://gw.wmcloud.com/mercury/databooks/"+unicode(u"国民经济行业分类与代码表.xls")
cookie = {"cloud-sso-token":"CF901E702906CBD358C5018D0AFBAA12"}
print "test"
# Out:
# test

# %%
import requests

# %%
a = requests.get(url,cookies=cookie)

# %%
# %quickref

# %%
a.text
# Out:
# u'\ufffd\ufffd\x11\ufffd\ufffd\ufffd\x1a\ufffd\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00>\x00\x03\x00\ufffd\ufffd\t\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\ufffd\x00\x00\x00\x01\x00\x00\x00\ufffd\ufffd\ufffd\ufffd\x00\x00\x00\x00\x00\x00\x00\x00D\x00\x00\x00\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd\ufffd
# ...

# %%
with open("1.csv", "wb") as f:
    f.write(a.text)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-13-e7ed4bfac089> in <module>()
#       1 with open("1.csv", "wb") as f:
# ----> 2     f.write(a.text)
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 0-1: ordinal not in range(128)

# %%
import urllib

# %%
urllib.urlretrieve?

# %%
urllib.urlretrieve("https://gw.wmcloud.com/mercury/databooks/bank.csv")
# Out:
# ('/tmp/tmpbcG4Q_.csv', <httplib.HTTPMessage instance at 0x225ed88>)

# %%
opener = urllib2.build_opener()
opener.addheaders.append(('Cookie', 'cookiename=cookievalue'))

# %%
import urllib2
opener = urllib2.build_opener()
opener.addheaders.append(('Cookie', 'cloud-sso-token=CF901E702906CBD358C5018D0AFBAA12'))
f = opener.open("https://gw.wmcloud.com/mercury/databooks/bank.csv")

# %%
data = f.read() 
with open("bank.csv", "wb") as code:     
    code.write(data)

# %%
import requests

# %%
a=requests.get("https://gw.wmcloud.com/mercury/databooks/123.txt", cookies=cookie)

# %%
a.content
# Out:
# 'wahgoawiutrwao'

# %%
a??

# %%
a = !ls

# %%
a
# Out:
# ['1.csv',
#  'bank.csv',
#  'IPYTHON_NOTEBOOK_SERVER_WITH_SPARK_PID.txt',
#  'ipython_notebook_spark.bashrc',
#  'notebook-2015-03-09.txt',
#  'notebook-2015-03-10.txt',
#  'README.md',
#  'Spark as Service 1. SinaWeiboHDFS.ipynb',
#  'Spark as Service 2. Stock Factors.ipynb',
#  'Spark as Service 3. SinaWeiboStreaming.ipynb',
#  'spark-fire-4.ipynb',
#  'SparkSQL.ipynb',
#  'start-ipython-notebook-with-spark.sh']

# %%
import progressbar

# %%
import time

# %%
progress = progressbar.ProgressBar()
for i in progress(range(80)):
  time.sleep(0.1)
# Out:
#   1% |                                                                        |
#   3% |##                                                                      |
#   6% |####                                                                    |
#   8% |######                                                                  |
#  11% |########                                                                |
#  13% |#########                                                               |
#  16% |###########                                                             |
#  18% |#############                                                           |
#  21% |###############                                                         |
#  23% |#################                                                       |
#  26% |##################                                                      |
#  28% |####################                                                    |
# ...
